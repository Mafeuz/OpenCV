# %% [markdown]
# ## Jumping Jacks Verification (VGGNET) ##

# %%
import numpy as np
import matplotlib.pyplot as plt
import cv2
import time

# %%
import sys
sys.path.append("C:/Users/Mafeus/Desktop/Git_Repos/OpenCV")
sys.path.append('C:/Users/Mafeus/Desktop/Git_Repos/OpenCV/Gesture Recognition/modules')
import OpCV_Utils
import extractor_BODY

# %%
# MPII ref: http://human-pose.mpi-inf.mpg.de/
# Caffe Coco ref: http://cocodataset.org/#keypoints-2018

# %%
def body_keypoints_processing(image, model):
    
    start = time.time()
    
    h_input = 368
    w_input = int((h_input/image.shape[0])*image.shape[1])
    
    # Transform img to compatible blob format:
    blob_input = cv2.dnn.blobFromImage(image = image, scalefactor = 1.0/255, size = (w_input, h_input), 
                                       mean = (0,0,0), swapRB = False, crop = False)
    # Process image:
    model.setInput(blob_input)
    output = model.forward()
    
    end = time.time()
    
    print('Processing Time:', (end-start), 's')
    
    return output

# %%
def paint_numbers(image, output, number_of_points, point_color, line_color, limit=0.1):
        
    h_input = image.shape[0]
    w_input = image.shape[1]
    
    points = []
    
    height = output.shape[2]
    width = output.shape[3]

    for i in range(number_of_points):
        confidence_map = output[0, i, :, :]
        _, confidence, _, p_coord = cv2.minMaxLoc(confidence_map)

        x = (w_input*p_coord[0])/width
        y = (h_input*p_coord[1])/height

        if (confidence > limit):
            cv2.circle(image, (int(x), int(y)), 8, point_color, thickness = -1, lineType = cv2.FILLED)
            cv2.putText(image, '{}'.format(i), (int(x)+2, int(y)+2), cv2.FONT_HERSHEY_SIMPLEX, 1, 
                        (0, 0, 0), 3, lineType = cv2.LINE_AA)

            points.append((int(x), int(y)))

    return image, points

# %%
def paint_skeleton(image, points, body_keypoints_pairs, point_color, line_color, limit=0.1):
     
    h_input = image.shape[0]
    w_input = image.shape[1]
    
    point_color = (255, 128, 0)
    line_color = (7, 62, 248)
    
    size = cv2.resize(image, (w_input, h_input))
    soft_map = cv2.GaussianBlur(size, (3,3), 0, 0)
    mask_map = np.uint8(soft_map > limit)
    
    for pair in body_keypoints_pairs:
        a = pair[0]
        b = pair[1]

        if (points[a] and points[b]):
            cv2.line(image, points[a], points[b], line_color, 3)
            cv2.circle(image, points[a], 8, point_color, thickness = -1, lineType = cv2.LINE_AA)

            cv2.line(mask_map, points[a], points[b], line_color, 3)
            cv2.circle(mask_map, points[a], 8, point_color, thickness = -1, lineType = cv2.LINE_AA)

    return mask_map

# %%
def check_jumping_jacks(img_with_numbers, points):
    
    txt_point_color, txt_init_color, txt_ongoing_color = (10, 216, 245), (255, 0, 128), (192, 192, 192)

    font_size, line_size, circ_size, thickness = 1, 2, 8, 5
    font = cv2.FONT_HERSHEY_SIMPLEX
    
    close_legs_validate, open_legs_validate = 0, 0
    down_arms_validate, up_arms_validate = 0, 0

    # Arms:
    if (extractor_BODY.verify_arms_DOWN(points[0:8]) == True):
        # 25% of the movement completed
        down_arms_validate = 0.25
        cv2.line(img_with_numbers, points[0], points[1], line_color, line_size, lineType = cv2.LINE_AA)
        cv2.putText(img_with_numbers, " Arms: Initial Position", (50, 50), font, font_size, txt_init_color, 0, 
                    lineType=cv2.LINE_AA)
  
    elif (extractor_BODY.verify_arms_UP(points[0:8]) == True):
        # 50% of the movement completed
        up_arms_validate = 0.5
        cv2.line(img_with_numbers, points[0], points[1], line_color, line_size, lineType = cv2.LINE_AA)
        cv2.putText(img_with_numbers, " Arms: Final Position", (50, 50), font, font_size, txt_init_color, 0, 
                    lineType=cv2.LINE_AA)
    
    else:
        down_arms_validate = 0
        up_arms_validate = 0
        cv2.line(img_with_numbers, points[0], points[1], line_color, line_size, lineType = cv2.LINE_AA)
        cv2.putText(img_with_numbers, " Arms: ongoing.", (50, 50), font, font_size, txt_init_color, 0, 
                    lineType=cv2.LINE_AA)
    
    # Legs:
    if (extractor_BODY.verify_legs_OPEN(points[8:14]) == True):
        # 50% of the movement
        open_legs_validate = 0.5
        cv2.line(img_with_numbers, points[0], points[1], line_color, line_size, lineType = cv2.LINE_AA)
        cv2.putText(img_with_numbers, " Legs: Final Position", (50, 70), font, font_size, txt_init_color, 0, 
                    lineType=cv2.LINE_AA)

    elif (extractor_BODY.verify_legs_CLOSE(points[8:14]) == True):
        # 25% of the movement
        close_legs_validate = 0.25  
        cv2.line(img_with_numbers, points[0], points[1], line_color, line_size, lineType = cv2.LINE_AA)
        cv2.putText(img_with_numbers, " Legs: Initial Position", (50, 70), font, font_size, txt_init_color, 0, 
                    lineType=cv2.LINE_AA)
    
    else:
        open_legs_validate = 0
        close_legs_validate = 0
        cv2.line(img_with_numbers, points[0], points[1], line_color, line_size, lineType = cv2.LINE_AA)
        cv2.putText(img_with_numbers, " Legs: ongoing.", (50, 70), font, font_size, txt_init_color, 0, lineType=cv2.LINE_AA)

    if (up_arms_validate !=0 and open_legs_validate != 0):
        cv2.putText(img_with_numbers, "Valid Jumping Jack: " + str(int(up_arms_validate + open_legs_validate)),
                    (50, 200), font, font_size, txt_init_color, 0, 
                    lineType=cv2.LINE_AA)
        
    pass

# %%
# MPII config files:
mpi_proto_file_path = 'C:/Users/Mafeus/Desktop/CURSO reconhecimento gestos/pose/pose/body/mpi/pose_deploy_linevec_faster_4_stages.prototxt'
mpi_weights_file_path = 'C:/Users/Mafeus/Desktop/CURSO reconhecimento gestos/pose/pose/body/mpi/pose_iter_160000.caffemodel'

# Config MPI Caffe Model:
mpi_model = cv2.dnn.readNetFromCaffe(mpi_proto_file_path, mpi_weights_file_path)
mpi_number_of_points = 15
mpi_body_keypoints_pairs = [[0, 1], [1, 2], [2, 3], [3, 4], [1, 5], [5, 6], [6, 7], 
                       [1, 14], [14, 8], [8, 9], [9, 10], [14, 11], [11, 12], [12, 13]]

# %%
# Coco config files:
coco_proto_file_path = 'C:/Users/Mafeus/Desktop/CURSO reconhecimento gestos/pose/pose/body/coco/pose_deploy_linevec.prototxt'
coco_weights_file_path = 'C:/Users/Mafeus/Desktop/CURSO reconhecimento gestos/pose/pose/body/coco/pose_iter_440000.caffemodel'

# Config Coco Caffe Model:
coco_model = cv2.dnn.readNetFromCaffe(coco_proto_file_path, coco_weights_file_path)
coco_number_of_points = 18

# %%
# Load Video:
video = 'C:/Users/Mafeus/Desktop/CURSO reconhecimento gestos/imagens/imagens/body/videos/v1.mp4'
cap = cv2.VideoCapture(video)
success, frame = cap.read()
video_fps = cap.get(cv2.CAP_PROP_FPS)
point_color = (255, 128, 0)
line_color = (7, 62, 248)

recorded_video = cv2.VideoWriter("./result.avi", cv2.VideoWriter_fourcc(*'XVID'), 10, (frame.shape[1], frame.shape[0]))
    
while True:
    
    start = time.time()
    
    success, frame = cap.read()
    
    if not success:
        print('Server OFF')
        break
    
    # Keyboard Controls:
    
    key = cv2.waitKey(1) or 0xff   
        
    if key == ord('k'):
        break
    
    #######################################
    
    output = body_keypoints_processing(frame.copy(), mpi_model)
    
    img_with_numbers, points = paint_numbers(frame.copy(), output, mpi_number_of_points, point_color, line_color, limit=0.1)
    
    skeleton_img = paint_skeleton(img_with_numbers, points, mpi_body_keypoints_pairs, point_color, line_color, limit=0.1)
    
    check_jumping_jacks(img_with_numbers, points)
    
    #######################################
    
    end = time.time()

    frame_time = (end - start) + 0.0001
    #fps = np.floor(1/frame_time)
    fps = 1/frame_time
        
    if (fps > video_fps):
        time.sleep(1/video_fps)
        fps = video_fps
    
    final_frame = OpCV_Utils.stack_multiple_images([[frame, img_with_numbers], [skeleton_img]], scale=0.3)
    
    cv2.putText(final_frame, "FPS: {:.2f}".format(fps), (30,20), cv2.FONT_HERSHEY_SIMPLEX, 0.5, (0, 0, 255), 2)
    
    cv2.imshow("Output", final_frame)
    
    recorded_video.write(final_frame)
    
cv2.destroyAllWindows()
cap.release()
recorded_video.release()
# Out:
# Processing Time: 2.448348045349121 s
# Processing Time: 2.4027771949768066 s
# Processing Time: 2.2452919483184814 s
# Processing Time: 2.2041213512420654 s
# initial position
# Processing Time: 2.186286449432373 s
# initial position
# Processing Time: 2.1671056747436523 s
# initial position
# Processing Time: 2.1422107219696045 s
# initial position
# Processing Time: 2.146251916885376 s
# initial position
# Processing Time: 2.147228717803955 s
# Processing Time: 2.1365044116973877 s
# Processing Time: 2.1401150226593018 s
# Processing Time: 2.1530988216400146 s
# Processing Time: 2.1460652351379395 s
# Processing Time: 2.1210930347442627 s
# Processing Time: 2.119645833969116 s
# Processing Time: 2.1524112224578857 s
# Processing Time: 2.1492128372192383 s
# Processing Time: 2.1508753299713135 s
# Processing Time: 2.154991388320923 s
# Processing Time: 2.141883134841919 s
# Processing Time: 2.130497694015503 s
# Processing Time: 2.153913974761963 s
# Processing Time: 2.140744924545288 s
# Processing Time: 2.1836163997650146 s
# Processing Time: 2.1819722652435303 s
# Processing Time: 2.1232423782348633 s
# Processing Time: 2.1522109508514404 s
# Processing Time: 2.2885279655456543 s
# Processing Time: 2.4463353157043457 s
# Processing Time: 2.296457052230835 s
# Processing Time: 2.5758678913116455 s
# Processing Time: 2.2774999141693115 s
# Processing Time: 2.3737640380859375 s
# Processing Time: 2.2093496322631836 s
# Processing Time: 2.1339638233184814 s
# Processing Time: 2.1950724124908447 s
# Processing Time: 2.1458303928375244 s
# Processing Time: 2.175527811050415 s
# Processing Time: 2.1455254554748535 s
# Processing Time: 2.1348299980163574 s
# Processing Time: 2.151721239089966 s
# Processing Time: 2.186984062194824 s
# Processing Time: 2.169675827026367 s
# Processing Time: 2.1925339698791504 s
# Processing Time: 2.2196006774902344 s
# Processing Time: 2.1685705184936523 s
# Processing Time: 2.144531488418579 s
# Processing Time: 2.1975300312042236 s
# Processing Time: 2.146199941635132 s
# Processing Time: 2.1655938625335693 s
# Processing Time: 2.139824151992798 s
# Processing Time: 2.176443099975586 s
# Processing Time: 2.1354477405548096 s
# Processing Time: 2.1335830688476562 s
# Processing Time: 2.139178514480591 s
# Processing Time: 2.1704931259155273 s
# Processing Time: 2.1399295330047607 s
# Processing Time: 2.153552770614624 s
# initial position
# Processing Time: 2.1534154415130615 s
# initial position
# Processing Time: 2.2008891105651855 s
# initial position
# Processing Time: 2.4012491703033447 s
# initial position
# Processing Time: 2.170785427093506 s
# initial position
# Processing Time: 2.165919542312622 s
# initial position
# Processing Time: 2.1636831760406494 s
# initial position
# Processing Time: 2.1679577827453613 s
# initial position
# Processing Time: 2.155827045440674 s
# initial position
# Processing Time: 2.1477394104003906 s
# initial position
# Processing Time: 2.1534342765808105 s
# initial position
# Processing Time: 2.2412359714508057 s
# initial position
# Processing Time: 2.373821258544922 s
# initial position
# Processing Time: 2.3730058670043945 s
# initial position
# Processing Time: 2.1454756259918213 s
# initial position
# Processing Time: 2.1407508850097656 s
# initial position
# Processing Time: 2.1557326316833496 s
# Processing Time: 2.1716620922088623 s
# Processing Time: 2.215641736984253 s
# Processing Time: 2.1828436851501465 s
# Processing Time: 2.2026076316833496 s
# Processing Time: 2.1401209831237793 s
# Processing Time: 2.172511339187622 s
# Processing Time: 2.145817279815674 s
# Processing Time: 2.1401073932647705 s
# Processing Time: 2.1306045055389404 s
# Processing Time: 2.1444599628448486 s
# Processing Time: 2.140092611312866 s
# Processing Time: 2.161712646484375 s
# Processing Time: 2.1519765853881836 s
# Processing Time: 2.1565964221954346 s
# Processing Time: 2.1571879386901855 s
# Processing Time: 2.122933864593506 s
# Processing Time: 2.171354293823242 s
# Processing Time: 2.1730527877807617 s
# Processing Time: 2.138484477996826 s
# Processing Time: 2.1486427783966064 s
# Processing Time: 2.1453514099121094 s
# Processing Time: 2.1713757514953613 s
# Processing Time: 2.202598810195923 s
# Processing Time: 2.204467535018921 s
# Processing Time: 2.158221960067749 s
# Processing Time: 2.1401162147521973 s
# Processing Time: 2.183037757873535 s
# Processing Time: 2.163076400756836 s
# Processing Time: 2.183335304260254 s
# Processing Time: 2.124499797821045 s
# Processing Time: 2.1485543251037598 s
# Processing Time: 2.1310529708862305 s
# Processing Time: 2.1666595935821533 s
# Processing Time: 2.1667916774749756 s
# Processing Time: 2.154775381088257 s
# Processing Time: 2.124438762664795 s
# Processing Time: 2.1263668537139893 s
# Processing Time: 2.1527085304260254 s
# Processing Time: 2.1681058406829834 s
# Processing Time: 2.155735969543457 s
# Processing Time: 2.138328790664673 s
# Processing Time: 2.149836301803589 s
# Processing Time: 2.144080877304077 s
# Processing Time: 2.158468008041382 s
# Processing Time: 2.159102201461792 s
# Processing Time: 2.1518819332122803 s
# Processing Time: 2.1369385719299316 s
# Processing Time: 2.1329519748687744 s
# Processing Time: 2.128626585006714 s
# Processing Time: 2.1398136615753174 s
# initial position
# Processing Time: 2.162903070449829 s
# initial position
# Processing Time: 2.160569667816162 s
# initial position
# Processing Time: 2.121555805206299 s
# initial position
# Processing Time: 2.1299779415130615 s
# initial position
# Processing Time: 2.161093235015869 s
# initial position
# Processing Time: 2.16849946975708 s
# initial position
# Processing Time: 2.168504238128662 s
# initial position
# Processing Time: 2.153406858444214 s
# initial position
# Processing Time: 2.1612138748168945 s
# initial position
# Processing Time: 2.1229279041290283 s
# initial position
# Processing Time: 2.1776199340820312 s
# Processing Time: 2.1557319164276123 s
# Processing Time: 2.1420202255249023 s
# Processing Time: 2.138270139694214 s
# Processing Time: 2.1394102573394775 s
# Processing Time: 2.15621018409729 s
# Processing Time: 2.1550207138061523 s
# Processing Time: 2.141326427459717 s
# Processing Time: 2.140120267868042 s
# Processing Time: 2.155742645263672 s
# Processing Time: 2.1597800254821777 s
# Processing Time: 2.1341607570648193 s
# Processing Time: 2.1394593715667725 s
# Processing Time: 2.147637367248535 s
# Processing Time: 2.139008045196533 s
# Processing Time: 2.146738052368164 s
# Processing Time: 2.1409754753112793 s
# Processing Time: 2.140119791030884 s
# Processing Time: 2.1825621128082275 s
# Processing Time: 2.1747772693634033 s
# Processing Time: 2.14070200920105 s
# Processing Time: 2.1401209831237793 s
# Processing Time: 2.124498128890991 s
# Processing Time: 2.1284525394439697 s
# Processing Time: 2.153984546661377 s
# Processing Time: 2.1576602458953857 s
# Processing Time: 2.140115261077881 s
# Processing Time: 2.1392364501953125 s
# Processing Time: 2.230123281478882 s
# Processing Time: 2.15167498588562 s
# Processing Time: 2.3100993633270264 s
# Processing Time: 2.9762229919433594 s
# Processing Time: 3.0779120922088623 s
# Processing Time: 2.8649938106536865 s
# Processing Time: 2.771514654159546 s
# Processing Time: 2.1538286209106445 s
# Server OFF

# %%
OpCV_Utils.show_single_image_plt(cv2.cvtColor(final_frame, cv2.COLOR_BGR2RGB), 'Output', fig_size = (10,10))
