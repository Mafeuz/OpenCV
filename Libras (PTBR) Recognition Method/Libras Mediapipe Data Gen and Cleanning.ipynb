# %% [markdown]
# ### Creating Dataframe from Mediapipe Output for Image Dataset

# %%
import numpy as np
import time
import matplotlib.pyplot as plt
import cv2
import mediapipe as mp
from IPython.display import clear_output
import pandas as pd

# %%
import sys
sys.path.append('C:/Users/Mafeus/Desktop/Git_Repos/OpenCV')
import OpCV_Utils

# %%
import glob

# %%
dataset_path = 'C:/Users/Mafeus/Desktop/libras_dataset_mdp'

# %%
A_imgs = glob.glob(dataset_path + '/A/' + '*.png')
B_imgs = glob.glob(dataset_path + '/B/' + '*.png')
C_imgs = glob.glob(dataset_path + '/C/' + '*.png')
D_imgs = glob.glob(dataset_path + '/D/' + '*.png')
E_imgs = glob.glob(dataset_path + '/E/' + '*.png')
F_imgs = glob.glob(dataset_path + '/F/' + '*.png')
G_imgs = glob.glob(dataset_path + '/G/' + '*.png')
I_imgs = glob.glob(dataset_path + '/I/' + '*.png')
L_imgs = glob.glob(dataset_path + '/L/' + '*.png')
M_imgs = glob.glob(dataset_path + '/M/' + '*.png')
N_imgs = glob.glob(dataset_path + '/N/' + '*.png')
O_imgs = glob.glob(dataset_path + '/O/' + '*.png')
P_imgs = glob.glob(dataset_path + '/P/' + '*.png')
Q_imgs = glob.glob(dataset_path + '/Q/' + '*.png')
R_imgs = glob.glob(dataset_path + '/R/' + '*.png')
S_imgs = glob.glob(dataset_path + '/S/' + '*.png')
T_imgs = glob.glob(dataset_path + '/T/' + '*.png')
U_imgs = glob.glob(dataset_path + '/U/' + '*.png')
V_imgs = glob.glob(dataset_path + '/V/' + '*.png')
W_imgs = glob.glob(dataset_path + '/W/' + '*.png')
X_imgs = glob.glob(dataset_path + '/X/' + '*.png')
Y_imgs = glob.glob(dataset_path + '/Y/' + '*.png')

all_imgs = [A_imgs, B_imgs, C_imgs, D_imgs, E_imgs, F_imgs, G_imgs, I_imgs, L_imgs, M_imgs, N_imgs,
            O_imgs, P_imgs, Q_imgs, R_imgs, S_imgs, T_imgs, U_imgs, V_imgs, W_imgs, X_imgs, Y_imgs]

# %%
def hand_detection_no_scaled(results):
    
    for handLandmarks in results.multi_hand_landmarks:
            
        landmarks_list = []
            
        for id, lm in enumerate(handLandmarks.landmark):
            cX, cY  = lm.x, lm.y
        
            landmarks_list.append([id, cX, cY])
                            
        return landmarks_list

# %%
# Letter Classification by getting Mediapipe Hand Detection Ouput Values:

# Object Instances:
mpDraw = mp.solutions.drawing_utils
mpHands = mp.solutions.hands

letters = ['A', 'B', 'C', 'D', 'E', 'F', 'G', 'I', 'L', 'M', 'N', 'O', 'P', 'Q', 'R', 'S', 'T', 'U', 'V', 'W', 'X', 'Y']

for i, letter_imgs in enumerate(all_imgs):
        
    letter = letters[i]
    
    for j, img in enumerate(letter_imgs):
        
        read_img = cv2.imread(img)
        
        hands = mpHands.Hands(static_image_mode=True, max_num_hands=1, min_detection_confidence=0.4, min_tracking_confidence=0.4)
        results = hands.process(cv2.cvtColor(read_img, cv2.COLOR_BGR2RGB))
                
        if results.multi_hand_landmarks:
            lm = hand_detection_no_scaled(results)
            
            work_array = np.array([i, lm[0][1], lm[0][2], lm[1][1], lm[1][2], lm[2][1], lm[2][2],
                                      lm[3][1], lm[3][2], lm[4][1], lm[4][2], lm[5][1], lm[5][2],
                                      lm[6][1], lm[6][2], lm[7][1], lm[7][2], lm[8][1], lm[8][2],
                                      lm[9][1], lm[9][2], lm[10][1], lm[10][2], lm[11][1], lm[11][2],
                                      lm[12][1], lm[12][2], lm[13][1], lm[13][2], lm[14][1], lm[14][2],
                                      lm[15][1], lm[15][2], lm[16][1], lm[16][2], lm[17][1], lm[17][2],
                                      lm[18][1], lm[18][2], lm[19][1], lm[19][2], lm[20][1], lm[20][2],], dtype=np.float32)
            
            if (i == 0) & (j == 0):
                data_array = work_array.copy()
            
            if (j > 0):
                data_array = np.vstack((data_array, work_array))
            
            clear_output(wait=True)
            print(letter, '-', j, '-', work_array[0], work_array[1], work_array[21])
            
dataframe = pd.DataFrame(data_array)
dataframe.to_csv('hands_dataframe', index=False)

# %% [markdown]
# #### Individual Letter Dataframe Creation:

# %%
# Letter Classification by getting Mediapipe Hand Detection Ouput Values:

# Object Instances:
# mpDraw = mp.solutions.drawing_utils

letter = 'Y'
i = 21

not_detected = 0

for k in range(6):

    for j, img in enumerate(Y_imgs[k*40:k*40 +40]):

        read_img = cv2.imread(img)

        mpHands = mp.solutions.hands
        hands = mpHands.Hands(static_image_mode=True, max_num_hands=1, min_detection_confidence=0.4, min_tracking_confidence=0.4)
        results = hands.process(cv2.cvtColor(read_img, cv2.COLOR_BGR2RGB))

        if results.multi_hand_landmarks:
            lm = hand_detection_no_scaled(results)

            work_array = np.array([i, lm[0][1], lm[0][2], lm[1][1], lm[1][2], lm[2][1], lm[2][2],
                                          lm[3][1], lm[3][2], lm[4][1], lm[4][2], lm[5][1], lm[5][2],
                                          lm[6][1], lm[6][2], lm[7][1], lm[7][2], lm[8][1], lm[8][2],
                                          lm[9][1], lm[9][2], lm[10][1], lm[10][2], lm[11][1], lm[11][2],
                                          lm[12][1], lm[12][2], lm[13][1], lm[13][2], lm[14][1], lm[14][2],
                                          lm[15][1], lm[15][2], lm[16][1], lm[16][2], lm[17][1], lm[17][2],
                                          lm[18][1], lm[18][2], lm[19][1], lm[19][2], lm[20][1], lm[20][2],], dtype=np.float32)

            if (j == 0):
                data_array = work_array.copy()

            if (j > 0):
                data_array = np.vstack((data_array, work_array))

                clear_output(wait=False)
                print(letter, '-', k, j, '-', work_array[0], work_array[1], work_array[21])

        else:
            not_detected +=1

    dataframe = pd.DataFrame(data_array)
    dataframe.to_csv('Y_dataframe_{}'.format(k), index=False)
    
print('Number of No Detections:', not_detected)
print('DONE')

# %%
letters = ['O', 'P', 'Q', 'R', 'S', 'T', 'U', 'V', 'W', 'X', 'Y']

for letter in letters:
    
    df0 = pd.read_csv(letter + '_dataframe_0')
    df1 = pd.read_csv(letter + '_dataframe_1')
    df2 = pd.read_csv(letter + '_dataframe_2')
    df3 = pd.read_csv(letter + '_dataframe_3')
    df4 = pd.read_csv(letter + '_dataframe_4')
    df5 = pd.read_csv(letter + '_dataframe_5')

    final_df = pd.concat([df0, df1, df2, df3, df4, df5], ignore_index=True, axis=0)
    final_df.to_csv(letter + '_dataframe', index=False)

# %%
dfA = pd.read_csv('A_dataframe')
dfB = pd.read_csv('B_dataframe')
dfC = pd.read_csv('C_dataframe')
dfD = pd.read_csv('D_dataframe')
dfE = pd.read_csv('E_dataframe')
dfF = pd.read_csv('F_dataframe')
dfG = pd.read_csv('G_dataframe')
dfI = pd.read_csv('I_dataframe')
dfL = pd.read_csv('L_dataframe')
dfM = pd.read_csv('M_dataframe')
dfN = pd.read_csv('N_dataframe')
dfO = pd.read_csv('O_dataframe')
dfP = pd.read_csv('P_dataframe')
dfQ = pd.read_csv('Q_dataframe')
dfR = pd.read_csv('R_dataframe')
dfS = pd.read_csv('S_dataframe')
dfT = pd.read_csv('T_dataframe')
dfU = pd.read_csv('U_dataframe')
dfV = pd.read_csv('V_dataframe')
dfW = pd.read_csv('W_dataframe')
dfX = pd.read_csv('X_dataframe')
dfY = pd.read_csv('Y_dataframe')

hands_df = pd.concat([dfA, dfB, dfC, dfD, dfE, dfF,
                      dfG, dfI, dfL, dfM, dfN, dfO,
                      dfP, dfQ, dfR, dfS, dfT, dfU,
                      dfV, dfW, dfX, dfY], ignore_index=True, axis=0)

# %%
hands_df.to_csv('hands_dataframe', index=False)

# %%
hands_df_read = pd.read_csv('hands_dataframe')
hands_df_read
# Out:
#          0         1         2         3         4         5         6  \
# 0      0.0  0.530610  0.734979  0.687852  0.695875  0.772122  0.560489
# 1      0.0  0.648609  0.859351  0.778897  0.797901  0.832064  0.652105
# 2      0.0  0.361423  0.859630  0.224011  0.804758  0.173517  0.667868
# 3      0.0  0.767182  0.829417  0.873378  0.738796  0.873948  0.582669
# 4      0.0  0.483996  0.738014  0.326520  0.687574  0.235558  0.559320
# ...    ...       ...       ...       ...       ...       ...       ...
# 5217  21.0  0.554259  0.625441  0.464854  0.553347  0.433579  0.437875
# 5218  21.0  0.448022  0.621944  0.541257  0.553962  0.559150  0.434892
# 5219  21.0  0.483697  0.557480  0.586212  0.504271  0.663735  0.398531
# 5220  21.0  0.521369  0.562645  0.403477  0.501175  0.321168  0.385726
# 5221  21.0  0.491919  0.547438  0.595190  0.489435  0.656917  0.379424
#
#              7         8         9  ...        33        34        35  \
# 0     0.777391  0.444213  0.785670  ...  0.529562  0.619644  0.391117
# 1     0.818550  0.546344  0.850461  ...  0.638657  0.776330  0.464930
# 2     0.179654  0.562697  0.152707  ...  0.365145  0.773470  0.538554
# 3     0.823329  0.485701  0.829521  ...  0.724968  0.739878  0.517911
# 4     0.221129  0.456594  0.203319  ...  0.467640  0.639272  0.597188
# ...        ...       ...       ...  ...       ...       ...       ...
# 5217  0.420882  0.355958  0.388358  ...  0.619229  0.483154  0.779483
# 5218  0.563110  0.343262  0.591839  ...  0.388379  0.480652  0.216528
# 5219  0.707334  0.314225  0.746055  ...  0.442312  0.398659  0.338834
# 5220  0.270212  0.293690  0.220791  ...  0.560415  0.392422  0.663392
# 5221  0.684472  0.287305  0.696737  ...  0.422534  0.404935  0.315240
#
#             36        37        38        39        40        41        42
# 0     0.545876  0.403106  0.496368  0.445098  0.573567  0.467922  0.626696
# 1     0.663796  0.510593  0.622864  0.560984  0.693026  0.587580  0.746618
# 2     0.669886  0.507316  0.643539  0.459220  0.710207  0.440000  0.761474
# 3     0.667061  0.545780  0.612058  0.618518  0.671339  0.660227  0.716618
# 4     0.538383  0.606877  0.498030  0.572900  0.572647  0.546903  0.626232
# ...        ...       ...       ...       ...       ...       ...       ...
# 5217  0.457556  0.862940  0.387345  0.911639  0.341631  0.955237  0.295481
# 5218  0.477261  0.125023  0.403096  0.080850  0.359216  0.043015  0.313312
# 5219  0.346869  0.288285  0.262188  0.260030  0.212683  0.240896  0.168712
# 5220  0.349528  0.709097  0.268464  0.740416  0.219352  0.763030  0.174171
# 5221  0.361236  0.252691  0.277596  0.214987  0.232511  0.188037  0.191336
#
# [5222 rows x 43 columns]
